# %% [markdown]
# <a href="https://colab.research.google.com/github/vapaul10/Portfolio-of-Valeri/blob/main/Copy_of_Random_Numbers_Sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#### Sample of Data Visualization

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
## Generate 100 random Data Points along 3 dimensions
x, y, scale = np.random.randn(3, 150)
fig, ax = plt.subplots()

## Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Some random data, crated with JupyterLab!")
plt.show()
